# %%
import pandas as pd

# %%
file = "asmr_merge_updated.csv"

# read file into pandas
asmr = pd.read_csv(file)
asmr.head()
# Out:
#    Unnamed: 0               channel  \
# 0           0              Angelica
# 1           1  ArticulateDesignASMR
# 2          54       ASMRCherryCrush
# 3           6             ASMRctica
# 4           2           ASMRDarling
#
#                                                  url  rank  birthyear   age  \
# 0  https://www.youtube.com/channel/UCq7jt5BQ6LTUL...  33.0        NaN   NaN
# 1  https://www.youtube.com/channel/UCOkFff6Mg5YEy...  46.0        NaN   NaN
# 2  https://www.youtube.com/channel/UCoNfsDH8sZe13...  28.0     1990.0  29.0
# 3  https://www.youtube.com/channel/UCi8QgZckGYg3R...   NaN        NaN   NaN
# 4  https://www.youtube.com/channel/UCikebqFWoT3QC...   4.0     1997.0  22.0
#
#   uploads     subs total_views channel_creation gender country       category  \
# 0     284   164223    28180506         8/2/2015      F      US         People
# 1      99    83757    12107764        7/24/2016      M      GB         People
# ...

# %%
asmr.count()
# Out:
# Unnamed: 0          58
# channel             58
# url                 58
# rank                49
# birthyear           45
# age                 45
# uploads             58
# subs                58
# total_views         58
# channel_creation    58
# gender              57
# country             57
# category            58
# twitter             58
# instagram           58
# twitch              58
# facebook            58
# type                58
# sb_url              58
# dtype: int64

# %%
asmr.sort_values(['rank'])
# Out:
#     Unnamed: 0               channel  \
# 6            4         ASMRKittyKlaw
# 24          22              GibiASMR
# 23          21  GentleWhisperingASMR
# 4            2           ASMRDarling
# 5            3              ASMRGlow
# 22          57      FrivolousFoxASMR
# 57          53       WhispersRedASMR
# 7            5             ASMRPPOMO
# 40          36           PelageaASMR
# 25          23         GoodnightMoon
# 36          32           MassageASMR
# 30          58            Jojo'sAsmr
# 18          55         EphemeralRift
# 31          59      KarunaSatoriASMR
# 42          38        RaffyTaphyASMR
# 20          56              fastASMR
# 8            7          ASMRrequests
# 27          25    HeatherFeatherASMR
# 44          40              SAS-ASMR
# 48          60        softlygaloshes
# 19          19         FairyCharASMR
# 41          37              PJDreams
# 32          28             LatteASMR
# 17          18              Dr.TASMR
# ...

# %%
asmr.groupby('twitter').count()
# Out:
#          Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# twitter
# False            21       21   21    17         15   15       21    21
# True             37       37   37    32         30   30       37    37
#
#          total_views  channel_creation  gender  country  category  instagram  \
# twitter
# False             21                21      21       20        21         21
# True              37                37      36       37        37         37
#
#          twitch  facebook  type  sb_url
# twitter
# False        21        21    21      21
# True         37        37    37      37

# %%
asmr.groupby('instagram').count()
# Out:
#            Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# instagram
# False              19       19   19    17         11   11       19    19
# True               39       39   39    32         34   34       39    39
#
#            total_views  channel_creation  gender  country  category  twitter  \
# instagram
# False               19                19      19       18        19       19
# True                39                39      38       39        39       39
#
#            twitch  facebook  type  sb_url
# instagram
# False          19        19    19      19
# True           39        39    39      39

# %%
asmr.groupby('facebook').count()
# Out:
#           Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# facebook
# False             29       29   29    21         21   21       29    29
# True              29       29   29    28         24   24       29    29
#
#           total_views  channel_creation  gender  country  category  twitter  \
# facebook
# False              29                29      28       28        29       29
# True               29                29      29       29        29       29
#
#           instagram  twitch  type  sb_url
# facebook
# False            29      29    29      29
# True             29      29    29      29

# %%
asmr.groupby('twitch').count()
# Out:
#         Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# twitch
# False           50       50   50    42         38   38       50    50
# True             8        8    8     7          7    7        8     8
#
#         total_views  channel_creation  gender  country  category  twitter  \
# twitch
# False            50                50      49       49        50       50
# True              8                 8       8        8         8        8
#
#         instagram  facebook  type  sb_url
# twitch
# False          50        50    50      50
# True            8         8     8       8
