# %%
import pandas as pd
import numpy as np
import datetime

# %%
file = "visualization/resources/url_df_updated.csv"

# read file into pandas
asmr = pd.read_csv(file)
asmr.head()
# Out:
#    Unnamed: 0        channel  \
# 0           0       Angelica
# 1           1      ASMRctica
# 2           2    ASMRDarling
# 3           3       ASMRGlow
# 4           4  ASMRKittyKlaw
#
#                                                  url  rank  birthyear   age  \
# 0  https://www.youtube.com/channel/UCq7jt5BQ6LTUL...  33.0        NaN   NaN
# 1  https://www.youtube.com/channel/UCi8QgZckGYg3R...   NaN        NaN   NaN
# 2  https://www.youtube.com/channel/UCikebqFWoT3QC...   4.0     1997.0  22.0
# 3  https://www.youtube.com/channel/UCFmL725KKPx2U...   5.0     1994.0  25.0
# 4  https://www.youtube.com/channel/UCo-gAYrvd7WIr...   1.0        NaN   NaN
#
#    uploads     subs  total_views channel_creation gender country  \
# 0      284   164223     28180506         8/2/2015      F      US
# 1       76    27066      4070797        9/24/2015      M      SE
# 2      153  2250614    417889554       12/11/2014      F      US
# ...

# %%
asmr.count()
# Out:
# Unnamed: 0          50
# channel             50
# url                 50
# rank                43
# birthyear           39
# age                 39
# uploads             50
# subs                50
# total_views         50
# channel_creation    50
# gender              50
# country             50
# category            50
# twitter             50
# instagram           50
# twitch              50
# facebook            50
# type                50
# sb_url              50
# dtype: int64

# %%
asmrAnalysis = asmr[['channel', 'birthyear', 'age', 'uploads', 'subs', 'total_views', 'channel_creation', 'gender', 
                     'country', 'category', 'twitter', 'instagram', 'twitch', 'facebook', 'type']]

# %%
asmrAnalysis
# Out:
#                  channel  birthyear   age  uploads     subs  total_views  \
# 0               Angelica        NaN   NaN      284   164223     28180506
# 1              ASMRctica        NaN   NaN       76    27066      4070797
# 2            ASMRDarling     1997.0  22.0      153  2250614    417889554
# 3               ASMRGlow     1994.0  25.0      157   723721    119915280
# 4          ASMRKittyKlaw        NaN   NaN      184   887195    141334295
# 5              ASMRPPOMO     1992.0  27.0      334  1703334    351067922
# 6           ASMRrequests     1991.0  28.0      201   500041    124203848
# 7         ASMRSoundSpace        NaN   NaN       57   189710     31102900
# 8              ASMRSurge        NaN   NaN      142   651738    125914998
# 9            ASMRTheChew     1971.0  48.0     1624   561606    113489035
# 10           Bluewhisper     1990.0  29.0       75      338        46399
# 11      CreativeCalmASMR     1992.0  27.0      267   202232     32720764
# ...

# %%
asmrAnalysis['channel_creation_year'] = pd.DatetimeIndex(asmrAnalysis['channel_creation']).year
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
asmrAnalysis
# Out:
#                  channel  birthyear   age  uploads     subs  total_views  \
# 0               Angelica        NaN   NaN      284   164223     28180506
# 1              ASMRctica        NaN   NaN       76    27066      4070797
# 2            ASMRDarling     1997.0  22.0      153  2250614    417889554
# 3               ASMRGlow     1994.0  25.0      157   723721    119915280
# 4          ASMRKittyKlaw        NaN   NaN      184   887195    141334295
# 5              ASMRPPOMO     1992.0  27.0      334  1703334    351067922
# 6           ASMRrequests     1991.0  28.0      201   500041    124203848
# 7         ASMRSoundSpace        NaN   NaN       57   189710     31102900
# 8              ASMRSurge        NaN   NaN      142   651738    125914998
# 9            ASMRTheChew     1971.0  48.0     1624   561606    113489035
# 10           Bluewhisper     1990.0  29.0       75      338        46399
# 11      CreativeCalmASMR     1992.0  27.0      267   202232     32720764
# ...

# %%
asmrAnalysisv2 = asmrAnalysis[['channel', 'uploads', 'subs', 'total_views', 'channel_creation_year', 'gender', 
                     'country', 'category', 'twitter', 'instagram', 'twitch', 'facebook', 'type']]

# %%
asmrAnalysisv2
# Out:
#                  channel  uploads     subs  total_views  \
# 0               Angelica      284   164223     28180506
# 1              ASMRctica       76    27066      4070797
# 2            ASMRDarling      153  2250614    417889554
# 3               ASMRGlow      157   723721    119915280
# 4          ASMRKittyKlaw      184   887195    141334295
# 5              ASMRPPOMO      334  1703334    351067922
# 6           ASMRrequests      201   500041    124203848
# 7         ASMRSoundSpace       57   189710     31102900
# 8              ASMRSurge      142   651738    125914998
# 9            ASMRTheChew     1624   561606    113489035
# 10           Bluewhisper       75      338        46399
# 11      CreativeCalmASMR      267   202232     32720764
# 12               DrTASMR      308   315064     89237889
# 13         EphemeralRift     1231   595015    229702976
# 14         FairyCharASMR      253   412643     92724646
# 15              fastASMR      589   410536    119438613
# ...

# %%
asmrAnalysisv2.groupby('twitter').count()
# Out:
#          channel  uploads  subs  total_views  channel_creation_year  gender  \
# twitter
# False         17       17    17           17                     17      17
# True          33       33    33           33                     33      33
#
#          country  category  instagram  twitch  facebook  type
# twitter
# False         17        17         17      17        17    17
# True          33        33         33      33        33    33

# %%
asmrAnalysisv2.groupby('instagram').count()
# Out:
#            channel  uploads  subs  total_views  channel_creation_year  gender  \
# instagram
# False           17       17    17           17                     17      17
# True            33       33    33           33                     33      33
#
#            country  category  twitter  twitch  facebook  type
# instagram
# False           17        17       17      17        17    17
# True            33        33       33      33        33    33

# %%
asmrAnalysisv2.groupby('facebook').count()
# Out:
#           channel  uploads  subs  total_views  channel_creation_year  gender  \
# facebook
# False          25       25    25           25                     25      25
# True           25       25    25           25                     25      25
#
#           country  category  twitter  instagram  twitch  type
# facebook
# False          25        25       25         25      25    25
# True           25        25       25         25      25    25

# %%
asmrAnalysisv2.groupby('twitch').count()
# Out:
#         channel  uploads  subs  total_views  channel_creation_year  gender  \
# twitch
# False        44       44    44           44                     44      44
# True          6        6     6            6                      6       6
#
#         country  category  twitter  instagram  facebook  type
# twitch
# False        44        44       44         44        44    44
# True          6         6        6          6         6     6

# %%
asmrAnalysisv2.groupby('gender').count()
# Out:
#         channel  uploads  subs  total_views  channel_creation_year  country  \
# gender
# F            36       36    36           36                     36       36
# M            14       14    14           14                     14       14
#
#         category  twitter  instagram  twitch  facebook  type
# gender
# F             36       36         36      36        36    36
# M             14       14         14      14        14    14

# %%
#asmrAnalysis_json = asmrAnalysisv2.to_json(orient='records', path_or_buf='asmrAnalysis.json')

# %%
#asmrAnalysis_json
# Out:
# '[{"channel":"Angelica","age":null,"uploads":284,"subs":164223,"total_views":28180506,"channel_creation_year":2015,"gender":"F","country":"US","category":"People","twitter":true,"instagram":true,"twitch":false,"facebook":false,"type":"channel"},{"channel":"ASMRctica","age":null,"uploads":76,"subs":27066,"total_views":4070797,"channel_creation_year":2015,"gender":"M","country":"SE","category":"Entertainment","twitter":true,"instagram":true,"twitch":false,"facebook":false,"type":"channel"},{"channel":"ASMRDarling","age":22.0,"uploads":153,"subs":2250614,"total_views":417889554,"channel_creation_year":2014,"gender":"F","country":"US","category":"Entertainment","twitter":true,"instagram":true,"twitch":false,"facebook":true,"type":"channel"},{"channel":"ASMRGlow","age":25.0,"uploads":157,"subs":723721,"total_views":119915280,"channel_creation_year":2016,"gender":"F","country":"ISR","category":"People","twitter":true,"instagram":true,"twitch":true,"facebook":false,"type":"channel"},{"chann
# ...

# %%
#asmrAnalysis[['channel', 'uploads']].to_records(index=False)
# Out:
# rec.array([('Angelica',  284), ('ASMRctica',   76), ('ASMRDarling',  153),
#            ('ASMRGlow',  157), ('ASMRKittyKlaw',  184),
#            ('ASMRPPOMO',  334), ('ASMRrequests',  201),
#            ('ASMRSoundSpace',   57), ('ASMRSurge',  142),
#            ('ASMRTheChew', 1624), ('Bluewhisper',   75),
#            ('CreativeCalmASMR',  267), ('DrTASMR',  308),
#            ('EphemeralRift', 1231), ('FairyCharASMR',  253),
#            ('fastASMR',  589), ('FredsVoiceASMR',  193),
#            ('FrivolousFoxASMR',  310), ('GentleWhisperingASMR',  393),
#            ('GibiASMR',  372), ('GoodnightMoon',   87),
#            ('GwenGwiz',  236), ('HeatherFeatherASMR',  319),
#            ('HermeticKitten',  508), ('JASMR',  307), ('JojosAsmr',  377),
#            ('KarunaSatoriASMR',  697), ('LatteASMR',  135),
#            ('LauraLemurexASMR',  264), ('MarnoASMR',  126),
#            ('MassageASMR',  691), ('MiniyuASMR',  570),
# ...

# %%
asmrAnalysisv2.columns[0:1]
# Out:
# Index(['channel', 'uploads', 'subs', 'total_views', 'channel_creation_year'], dtype='object')

# %%
asmrAnalysisv2.as_matrix(columns=asmrAnalysisv2.columns[0:1])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([['Angelica'],
#        ['ASMRctica'],
#        ['ASMRDarling'],
#        ['ASMRGlow'],
#        ['ASMRKittyKlaw'],
#        ['ASMRPPOMO'],
#        ['ASMRrequests'],
#        ['ASMRSoundSpace'],
#        ['ASMRSurge'],
#        ['ASMRTheChew'],
#        ['Bluewhisper'],
#        ['CreativeCalmASMR'],
#        ['DrTASMR'],
#        ['EphemeralRift'],
#        ['FairyCharASMR'],
#        ['fastASMR'],
#        ['FredsVoiceASMR'],
#        ['FrivolousFoxASMR'],
#        ['GentleWhisperingASMR'],
#        ['GibiASMR'],
#        ['GoodnightMoon'],
#        ['GwenGwiz'],
#        ['HeatherFeatherASMR'],
#        ['HermeticKitten'],
#        ['JASMR'],
#        ['JojosAsmr'],
#        ['KarunaSatoriASMR'],
#        ['LatteASMR'],
#        ['LauraLemurexASMR'],
# ...

# %%
asmrAnalysisv2.as_matrix(columns=asmrAnalysisv2.columns[2:3])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[ 164223],
#        [  27066],
#        [2250614],
#        [ 723721],
#        [ 887195],
#        [1703334],
#        [ 500041],
#        [ 189710],
#        [ 651738],
#        [ 561606],
#        [    338],
#        [ 202232],
#        [ 315064],
#        [ 595015],
#        [ 412643],
#        [ 410536],
#        [ 339108],
#        [1053497],
#        [1617151],
#        [1685347],
#        [ 430302],
#        [ 368466],
#        [ 507166],
#        [ 293771],
#        [ 119718],
#        [ 534532],
#        [ 626732],
#        [ 677225],
#        [ 153231],
#        [ 172940],
#        [ 753553],
#        [ 493734],
#        [ 233418],
#        [ 317551],
#        [ 784179],
#        [ 379590],
#        [ 417877],
#        [ 125597],
# ...

# %%
asmrAnalysisv2.as_matrix(columns=asmrAnalysisv2.columns[3:4])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[ 28180506],
#        [  4070797],
#        [417889554],
#        [119915280],
#        [141334295],
#        [351067922],
#        [124203848],
#        [ 31102900],
#        [125914998],
#        [113489035],
#        [    46399],
#        [ 32720764],
#        [ 89237889],
#        [229702976],
#        [ 92724646],
#        [119438613],
#        [ 53926121],
#        [232196121],
#        [578125378],
#        [429129059],
#        [ 59183471],
#        [ 39537838],
#        [155106841],
#        [ 71458273],
#        [ 19885236],
#        [117567758],
#        [146226984],
#        [138883059],
#        [ 33505260],
#        [ 18926397],
#        [283711132],
#        [159027656],
#        [ 53824452],
#        [ 97687202],
#        [161445940],
# ...

# %%
asmrAnalysisv2.as_matrix(columns=asmrAnalysisv2.columns[1:2])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[ 284],
#        [  76],
#        [ 153],
#        [ 157],
#        [ 184],
#        [ 334],
#        [ 201],
#        [  57],
#        [ 142],
#        [1624],
#        [  75],
#        [ 267],
#        [ 308],
#        [1231],
#        [ 253],
#        [ 589],
#        [ 193],
#        [ 310],
#        [ 393],
#        [ 372],
#        [  87],
#        [ 236],
#        [ 319],
#        [ 508],
#        [ 307],
#        [ 377],
#        [ 697],
#        [ 135],
#        [ 264],
#        [ 126],
#        [ 691],
#        [ 570],
#        [ 233],
#        [ 432],
#        [ 123],
#        [ 338],
#        [ 418],
#        [ 163],
#        [ 658],
#        [ 274],
#        [ 454],
#        [1521],
#        [ 135],
#        [ 280],
#        [ 445],
# ...
