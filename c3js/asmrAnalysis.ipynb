# %%
import pandas as pd

# %%
file = "asmr_merge.csv"

# read file into pandas
asmr = pd.read_csv(file)
asmr.head()
# Out:
#    Unnamed: 0               channel  \
# 0           0              Angelica
# 1           1  ArticulateDesignASMR
# 2           2           ASMRDarling
# 3           3              ASMRGlow
# 4           4         ASMRKittyKlaw
#
#                                                  url  rank  birthyear   age  \
# 0  https://www.youtube.com/channel/UCq7jt5BQ6LTUL...  33.0        NaN   NaN
# 1  https://www.youtube.com/channel/UCOkFff6Mg5YEy...  46.0        NaN   NaN
# 2  https://www.youtube.com/channel/UCikebqFWoT3QC...   4.0     1997.0  22.0
# 3  https://www.youtube.com/channel/UCFmL725KKPx2U...   5.0     1994.0  25.0
# 4  https://www.youtube.com/channel/UCo-gAYrvd7WIr...   1.0        NaN   NaN
#
#    uploads     subs  total_views channel_creation gender country  \
# 0    284.0   164223   28180506.0         8/2/2015      F      US
# 1     99.0    83757   12107764.0        7/24/2016      M      GB
# 2    153.0  2250614  417889554.0       12/11/2014      F      US
# ...

# %%
asmr.count()
# Out:
# Unnamed: 0          62
# channel             62
# url                 62
# rank                50
# birthyear           40
# age                 40
# uploads             62
# subs                62
# total_views         62
# channel_creation    50
# gender              50
# country             50
# category            50
# twitter             62
# instagram           62
# twitch              62
# facebook            62
# type                62
# sb_url              62
# dtype: int64

# %%
clean_asmr=asmr.dropna(subset=['rank'])
clean_asmr.count()
# Out:
# Unnamed: 0          50
# channel             50
# url                 50
# rank                50
# birthyear           40
# age                 40
# uploads             50
# subs                50
# total_views         50
# channel_creation    50
# gender              50
# country             50
# category            50
# twitter             50
# instagram           50
# twitch              50
# facebook            50
# type                50
# sb_url              50
# dtype: int64

# %%
clean_asmr.sort_values(['rank'])
# Out:
#     Unnamed: 0               channel  \
# 4            4         ASMRKittyKlaw
# 22          22              GibiASMR
# 21          21  GentleWhisperingASMR
# 2            2           ASMRDarling
# 3            3              ASMRGlow
# 57          57      FrivolousFoxASMR
# 53          53       WhispersRedASMR
# 5            5             ASMRPPOMO
# 36          36           PelageaASMR
# 23          23         GoodnightMoon
# 32          32           MassageASMR
# 58          58            Jojo'sAsmr
# 55          55         EphemeralRift
# 59          59      KarunaSatoriASMR
# 38          38        RaffyTaphyASMR
# 56          56              fastASMR
# 7            7          ASMRrequests
# 25          25    HeatherFeatherASMR
# 40          40              SAS-ASMR
# 60          60        softlygaloshes
# 19          19         FairyCharASMR
# 37          37              PJDreams
# 28          28             LatteASMR
# 18          18              Dr.TASMR
# ...

# %%
clean_asmr.groupby('twitter').count()
# Out:
#          Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# twitter
# False            18       18   18    18         13   13       18    18
# True             32       32   32    32         27   27       32    32
#
#          total_views  channel_creation  gender  country  category  instagram  \
# twitter
# False             18                18      18       18        18         18
# True              32                32      32       32        32         32
#
#          twitch  facebook  type  sb_url
# twitter
# False        18        18    18      18
# True         32        32    32      32

# %%
clean_asmr.groupby('instagram').count()
# Out:
#            Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# instagram
# False              17       17   17    17         11   11       17    17
# True               33       33   33    33         29   29       33    33
#
#            total_views  channel_creation  gender  country  category  twitter  \
# instagram
# False               17                17      17       17        17       17
# True                33                33      33       33        33       33
#
#            twitch  facebook  type  sb_url
# instagram
# False          17        17    17      17
# True           33        33    33      33

# %%
clean_asmr.groupby('facebook').count()
# Out:
#           Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# facebook
# False             22       22   22    22         16   16       22    22
# True              28       28   28    28         24   24       28    28
#
#           total_views  channel_creation  gender  country  category  twitter  \
# facebook
# False              22                22      22       22        22       22
# True               28                28      28       28        28       28
#
#           instagram  twitch  type  sb_url
# facebook
# False            22      22    22      22
# True             28      28    28      28

# %%
clean_asmr.groupby('twitch').count()
# Out:
#         Unnamed: 0  channel  url  rank  birthyear  age  uploads  subs  \
# twitch
# False           43       43   43    43         34   34       43    43
# True             7        7    7     7          6    6        7     7
#
#         total_views  channel_creation  gender  country  category  twitter  \
# twitch
# False            43                43      43       43        43       43
# True              7                 7       7        7         7        7
#
#         instagram  facebook  type  sb_url
# twitch
# False          43        43    43      43
# True            7         7     7       7
