# %%
import pandas as pd
import numpy as np
import datetime

# %%
file = "visualization/resources/url_df_updated.csv"

# read file into pandas
asmr = pd.read_csv(file)
asmr.head()
# Out:
#    Unnamed: 0        channel  \
# 0           0       Angelica
# 1           1      ASMRctica
# 2           2    ASMRDarling
# 3           3       ASMRGlow
# 4           4  ASMRKittyKlaw
#
#                                                  url  rank  birthyear   age  \
# 0  https://www.youtube.com/channel/UCq7jt5BQ6LTUL...  33.0        NaN   NaN
# 1  https://www.youtube.com/channel/UCi8QgZckGYg3R...   NaN        NaN   NaN
# 2  https://www.youtube.com/channel/UCikebqFWoT3QC...   4.0     1997.0  22.0
# 3  https://www.youtube.com/channel/UCFmL725KKPx2U...   5.0     1994.0  25.0
# 4  https://www.youtube.com/channel/UCo-gAYrvd7WIr...   1.0        NaN   NaN
#
#    uploads     subs  total_views channel_creation gender country  \
# 0      284   164223     28180506         8/2/2015      F      US
# 1       76    27066      4070797        9/24/2015      M      SE
# 2      153  2250614    417889554       12/11/2014      F      US
# ...

# %%
asmrAnalysis = asmr[['channel', 'uploads', 'subs', 'total_views', 'channel_creation']]

# %%
asmrAnalysis
# Out:
#                  channel  uploads     subs  total_views channel_creation
# 0               Angelica      284   164223     28180506         8/2/2015
# 1              ASMRctica       76    27066      4070797        9/24/2015
# 2            ASMRDarling      153  2250614    417889554       12/11/2014
# 3               ASMRGlow      157   723721    119915280       10/24/2016
# 4          ASMRKittyKlaw      184   887195    141334295        8/14/2015
# 5              ASMRPPOMO      334  1703334    351067922       10/22/2013
# 6           ASMRrequests      201   500041    124203848        5/17/2012
# 7         ASMRSoundSpace       57   189710     31102900        2/12/2016
# 8              ASMRSurge      142   651738    125914998        9/25/2012
# 9            ASMRTheChew     1624   561606    113489035        11/1/2015
# 10           Bluewhisper       75      338        46399        4/23/2015
# 11      CreativeCalmASMR      267   202232     32720764        9/29/2015
# ...

# %%
asmrAnalysis['channel_creation_year'] = pd.DatetimeIndex(asmrAnalysis['channel_creation']).year
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
asmrAnalysis
# Out:
#                  channel  uploads     subs  total_views channel_creation  \
# 0               Angelica      284   164223     28180506         8/2/2015
# 1              ASMRctica       76    27066      4070797        9/24/2015
# 2            ASMRDarling      153  2250614    417889554       12/11/2014
# 3               ASMRGlow      157   723721    119915280       10/24/2016
# 4          ASMRKittyKlaw      184   887195    141334295        8/14/2015
# 5              ASMRPPOMO      334  1703334    351067922       10/22/2013
# 6           ASMRrequests      201   500041    124203848        5/17/2012
# 7         ASMRSoundSpace       57   189710     31102900        2/12/2016
# 8              ASMRSurge      142   651738    125914998        9/25/2012
# 9            ASMRTheChew     1624   561606    113489035        11/1/2015
# 10           Bluewhisper       75      338        46399        4/23/2015
# 11      CreativeCalmASMR      267   202232     32720764        9/29/2015
# ...

# %%
asmrAnalysisv2 = asmrAnalysis[['channel', 'uploads', 'subs', 'total_views', 
                               'channel_creation_year']]

# %%
asmrAnalysisv2
# Out:
#                  channel  uploads     subs  total_views  channel_creation_year
# 0               Angelica      284   164223     28180506                   2015
# 1              ASMRctica       76    27066      4070797                   2015
# 2            ASMRDarling      153  2250614    417889554                   2014
# 3               ASMRGlow      157   723721    119915280                   2016
# 4          ASMRKittyKlaw      184   887195    141334295                   2015
# 5              ASMRPPOMO      334  1703334    351067922                   2013
# 6           ASMRrequests      201   500041    124203848                   2012
# 7         ASMRSoundSpace       57   189710     31102900                   2016
# 8              ASMRSurge      142   651738    125914998                   2012
# 9            ASMRTheChew     1624   561606    113489035                   2015
# 10           Bluewhisper       75      338        46399                   2015
# ...

# %%
asmrAnalysisv2['subs1k'] = asmrAnalysisv2['subs'].div(1000).round()

# %%
asmrAnalysisv2['views1m'] = asmrAnalysisv2['total_views'].div(1000000).round()

# %%
asmrAnalysisv2
# Out:
#                  channel  uploads     subs  total_views  \
# 0               Angelica      284   164223     28180506
# 1              ASMRctica       76    27066      4070797
# 2            ASMRDarling      153  2250614    417889554
# 3               ASMRGlow      157   723721    119915280
# 4          ASMRKittyKlaw      184   887195    141334295
# 5              ASMRPPOMO      334  1703334    351067922
# 6           ASMRrequests      201   500041    124203848
# 7         ASMRSoundSpace       57   189710     31102900
# 8              ASMRSurge      142   651738    125914998
# 9            ASMRTheChew     1624   561606    113489035
# 10           Bluewhisper       75      338        46399
# 11      CreativeCalmASMR      267   202232     32720764
# 12               DrTASMR      308   315064     89237889
# 13         EphemeralRift     1231   595015    229702976
# 14         FairyCharASMR      253   412643     92724646
# 15              fastASMR      589   410536    119438613
# ...

# %%
asmrAnalysisv3 = asmrAnalysisv2[['channel', 'uploads', 'subs1k', 'views1m', 
                               'channel_creation_year']]

# %%
asmrAnalysisv3
# Out:
#                  channel  uploads  subs1k  views1m  channel_creation_year
# 0               Angelica      284   164.0     28.0                   2015
# 1              ASMRctica       76    27.0      4.0                   2015
# 2            ASMRDarling      153  2251.0    418.0                   2014
# 3               ASMRGlow      157   724.0    120.0                   2016
# 4          ASMRKittyKlaw      184   887.0    141.0                   2015
# 5              ASMRPPOMO      334  1703.0    351.0                   2013
# 6           ASMRrequests      201   500.0    124.0                   2012
# 7         ASMRSoundSpace       57   190.0     31.0                   2016
# 8              ASMRSurge      142   652.0    126.0                   2012
# 9            ASMRTheChew     1624   562.0    113.0                   2015
# 10           Bluewhisper       75     0.0      0.0                   2015
# 11      CreativeCalmASMR      267   202.0     33.0                   2015
# ...

# %%
scattr_channel = asmrAnalysisv3.as_matrix(columns=asmrAnalysisv3.columns[0:1])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
scattr_channel
# Out:
# array([['Angelica'],
#        ['ASMRctica'],
#        ['ASMRDarling'],
#        ['ASMRGlow'],
#        ['ASMRKittyKlaw'],
#        ['ASMRPPOMO'],
#        ['ASMRrequests'],
#        ['ASMRSoundSpace'],
#        ['ASMRSurge'],
#        ['ASMRTheChew'],
#        ['Bluewhisper'],
#        ['CreativeCalmASMR'],
#        ['DrTASMR'],
#        ['EphemeralRift'],
#        ['FairyCharASMR'],
#        ['fastASMR'],
#        ['FredsVoiceASMR'],
#        ['FrivolousFoxASMR'],
#        ['GentleWhisperingASMR'],
#        ['GibiASMR'],
#        ['GoodnightMoon'],
#        ['GwenGwiz'],
#        ['HeatherFeatherASMR'],
#        ['HermeticKitten'],
#        ['JASMR'],
#        ['JojosAsmr'],
#        ['KarunaSatoriASMR'],
#        ['LatteASMR'],
#        ['LauraLemurexASMR'],
#        ['MarnoASMR'],
#        ['MassageASMR'],
#        ['MiniyuASMR'],
#        ['MissASMR'],
#        ['OliviaKissperASMR'],
#        ['PelageaASMR'],
#        ['PJDreams'],
#        ['RapunzelASMR'],
# ...

# %%
scattr_upload = asmrAnalysisv3.as_matrix(columns=asmrAnalysisv3.columns[1:2])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
scattr_upload
# Out:
# array([[ 284],
#        [  76],
#        [ 153],
#        [ 157],
#        [ 184],
#        [ 334],
#        [ 201],
#        [  57],
#        [ 142],
#        [1624],
#        [  75],
#        [ 267],
#        [ 308],
#        [1231],
#        [ 253],
#        [ 589],
#        [ 193],
#        [ 310],
#        [ 393],
#        [ 372],
#        [  87],
#        [ 236],
#        [ 319],
#        [ 508],
#        [ 307],
#        [ 377],
#        [ 697],
#        [ 135],
#        [ 264],
#        [ 126],
#        [ 691],
#        [ 570],
#        [ 233],
#        [ 432],
#        [ 123],
#        [ 338],
#        [ 418],
#        [ 163],
#        [ 658],
#        [ 274],
#        [ 454],
#        [1521],
#        [ 135],
#        [ 280],
#        [ 445],
#        [  98],
#        [ 298],
#        [ 602],
#        [ 866],
#        [ 392]], dtype=int64)

# %%
scattr_subs = asmrAnalysisv3.as_matrix(columns=asmrAnalysisv3.columns[2:3])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
scattr_subs
# Out:
# array([[ 164.],
#        [  27.],
#        [2251.],
#        [ 724.],
#        [ 887.],
#        [1703.],
#        [ 500.],
#        [ 190.],
#        [ 652.],
#        [ 562.],
#        [   0.],
#        [ 202.],
#        [ 315.],
#        [ 595.],
#        [ 413.],
#        [ 411.],
#        [ 339.],
#        [1053.],
#        [1617.],
#        [1685.],
#        [ 430.],
#        [ 368.],
#        [ 507.],
#        [ 294.],
#        [ 120.],
#        [ 535.],
#        [ 627.],
#        [ 677.],
#        [ 153.],
#        [ 173.],
#        [ 754.],
#        [ 494.],
#        [ 233.],
#        [ 318.],
#        [ 784.],
#        [ 380.],
#        [ 418.],
#        [ 126.],
#        [ 202.],
#        [ 251.],
#        [ 332.],
#        [ 149.],
#        [ 158.],
#        [1618.],
#        [ 219.],
#        [ 161.],
#        [ 522.],
#        [ 130.],
#        [ 277.],
#        [ 684.]])

# %%
scattr_views = asmrAnalysisv3.as_matrix(columns=asmrAnalysisv3.columns[3:4])
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
scattr_views
# Out:
# array([[ 28.],
#        [  4.],
#        [418.],
#        [120.],
#        [141.],
#        [351.],
#        [124.],
#        [ 31.],
#        [126.],
#        [113.],
#        [  0.],
#        [ 33.],
#        [ 89.],
#        [230.],
#        [ 93.],
#        [119.],
#        [ 54.],
#        [232.],
#        [578.],
#        [429.],
#        [ 59.],
#        [ 40.],
#        [155.],
#        [ 71.],
#        [ 20.],
#        [118.],
#        [146.],
#        [139.],
#        [ 34.],
#        [ 19.],
#        [284.],
#        [159.],
#        [ 54.],
#        [ 98.],
#        [161.],
#        [ 58.],
#        [ 80.],
#        [ 21.],
#        [ 51.],
#        [ 41.],
#        [ 84.],
#        [ 48.],
#        [ 35.],
#        [372.],
#        [ 65.],
#        [ 28.],
#        [ 85.],
#        [ 28.],
#        [102.],
#        [177.]])

# %%
scattr_year = asmrAnalysisv3.as_matrix()
# Out:
# C:\Users\JF\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
scattr_year
# Out:
# array([['Angelica', 284, 164.0, 28.0, 2015],
#        ['ASMRctica', 76, 27.0, 4.0, 2015],
#        ['ASMRDarling', 153, 2251.0, 418.0, 2014],
#        ['ASMRGlow', 157, 724.0, 120.0, 2016],
#        ['ASMRKittyKlaw', 184, 887.0, 141.0, 2015],
#        ['ASMRPPOMO', 334, 1703.0, 351.0, 2013],
#        ['ASMRrequests', 201, 500.0, 124.0, 2012],
#        ['ASMRSoundSpace', 57, 190.0, 31.0, 2016],
#        ['ASMRSurge', 142, 652.0, 126.0, 2012],
#        ['ASMRTheChew', 1624, 562.0, 113.0, 2015],
#        ['Bluewhisper', 75, 0.0, 0.0, 2015],
#        ['CreativeCalmASMR', 267, 202.0, 33.0, 2015],
#        ['DrTASMR', 308, 315.0, 89.0, 2016],
#        ['EphemeralRift', 1231, 595.0, 230.0, 2011],
#        ['FairyCharASMR', 253, 413.0, 93.0, 2009],
#        ['fastASMR', 589, 411.0, 119.0, 2011],
#        ['FredsVoiceASMR', 193, 339.0, 54.0, 2011],
#        ['FrivolousFoxASMR', 310, 1053.0, 232.0, 2016],
#        ['GentleWhisperingASMR', 393, 1617.0, 578.0, 2011],
# ...
